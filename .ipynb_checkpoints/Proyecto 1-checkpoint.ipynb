# %% [markdown]
# ![bi.png](data:image/png;base64,...)

# %% [markdown]
# # Proyecto 1 - Analítica de Textos
# ### Andrés Sánchez (201821941), Daniel Rincón (201822574), Jhorman Caballero (201812920)

# %% [markdown]
# ## 0. Manejo de librerías y lectura de los datos.

# %%
# Librería para manejar las contracciones que se presentan en el inglés.

# Requiere Microsoft Visual C++ 14.0
# !pip install contractions
# !pip install textsearch
# Out:
# Requirement already satisfied: contractions in d:\anaconda\lib\site-packages (0.0.52)
# Requirement already satisfied: textsearch>=0.0.21 in d:\anaconda\lib\site-packages (from contractions) (0.0.21)
# Requirement already satisfied: pyahocorasick in d:\anaconda\lib\site-packages (from textsearch>=0.0.21->contractions) (1.4.2)
# Requirement already satisfied: anyascii in d:\anaconda\lib\site-packages (from textsearch>=0.0.21->contractions) (0.3.0)
# Requirement already satisfied: textsearch in d:\anaconda\lib\site-packages (0.0.21)
# Requirement already satisfied: pyahocorasick in d:\anaconda\lib\site-packages (from textsearch) (1.4.2)
# Requirement already satisfied: anyascii in d:\anaconda\lib\site-packages (from textsearch) (0.3.0)

# %%
# !pip install neattext
# !pip install textblob
# !pip install wordcloud
# !pip install eli5
# !pip install lime
# Out:
# Requirement already satisfied: neattext in d:\anaconda\lib\site-packages (0.1.2)
# Requirement already satisfied: textblob in d:\anaconda\lib\site-packages (0.15.3)
# Requirement already satisfied: nltk>=3.1 in d:\anaconda\lib\site-packages (from textblob) (3.6.3)
# Requirement already satisfied: joblib in d:\anaconda\lib\site-packages (from nltk>=3.1->textblob) (1.0.1)
# Requirement already satisfied: click in d:\anaconda\lib\site-packages (from nltk>=3.1->textblob) (8.0.1)
# Requirement already satisfied: regex in d:\anaconda\lib\site-packages (from nltk>=3.1->textblob) (2021.4.4)
# Requirement already satisfied: tqdm in d:\anaconda\lib\site-packages (from nltk>=3.1->textblob) (4.62.0)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from click->nltk>=3.1->textblob) (0.4.4)
# Requirement already satisfied: wordcloud in d:\anaconda\lib\site-packages (1.8.1)
# Requirement already satisfied: numpy>=1.6.1 in d:\anaconda\lib\site-packages (from wordcloud) (1.20.3)
# Requirement already satisfied: matplotlib in d:\anaconda\lib\site-packages (from wordcloud) (3.4.2)
# Requirement already satisfied: pillow in d:\anaconda\lib\site-packages (from wordcloud) (8.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\anaconda\lib\site-packages (from matplotlib->wordcloud) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda\lib\site-packages (from matplotlib->wordcloud) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda\lib\site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six in d:\anaconda\lib\site-packages (from cycler>=0.10->matplotlib->wordcloud) (1.16.0)
# Requirement already satisfied: eli5 in d:\anaconda\lib\site-packages (0.11.0)
# Requirement already satisfied: jinja2 in d:\anaconda\lib\site-packages (from eli5) (2.11.3)
# Requirement already satisfied: six in d:\anaconda\lib\site-packages (from eli5) (1.16.0)
# Requirement already satisfied: scikit-learn>=0.20 in d:\anaconda\lib\site-packages (from eli5) (0.24.2)
# Requirement already satisfied: attrs>16.0.0 in d:\anaconda\lib\site-packages (from eli5) (21.2.0)
# Requirement already satisfied: numpy>=1.9.0 in d:\anaconda\lib\site-packages (from eli5) (1.20.3)
# Requirement already satisfied: scipy in d:\anaconda\lib\site-packages (from eli5) (1.6.2)
# Requirement already satisfied: graphviz in d:\anaconda\lib\site-packages (from eli5) (0.17)
# Requirement already satisfied: tabulate>=0.7.7 in d:\anaconda\lib\site-packages (from eli5) (0.8.9)
# Requirement already satisfied: joblib>=0.11 in d:\anaconda\lib\site-packages (from scikit-learn>=0.20->eli5) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\anaconda\lib\site-packages (from scikit-learn>=0.20->eli5) (2.2.0)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\anaconda\lib\site-packages (from jinja2->eli5) (2.0.1)
# Requirement already satisfied: lime in d:\anaconda\lib\site-packages (0.2.0.1)
# Requirement already satisfied: matplotlib in d:\anaconda\lib\site-packages (from lime) (3.4.2)
# Requirement already satisfied: numpy in d:\anaconda\lib\site-packages (from lime) (1.20.3)
# Requirement already satisfied: tqdm in d:\anaconda\lib\site-packages (from lime) (4.62.0)
# Requirement already satisfied: scikit-image>=0.12 in d:\anaconda\lib\site-packages (from lime) (0.18.3)
# Requirement already satisfied: scikit-learn>=0.18 in d:\anaconda\lib\site-packages (from lime) (0.24.2)
# Requirement already satisfied: scipy in d:\anaconda\lib\site-packages (from lime) (1.6.2)
# Requirement already satisfied: imageio>=2.3.0 in d:\anaconda\lib\site-packages (from scikit-image>=0.12->lime) (2.9.0)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in d:\anaconda\lib\site-packages (from scikit-image>=0.12->lime) (8.3.1)
# Requirement already satisfied: PyWavelets>=1.1.1 in d:\anaconda\lib\site-packages (from scikit-image>=0.12->lime) (1.1.1)
# Requirement already satisfied: networkx>=2.0 in d:\anaconda\lib\site-packages (from scikit-image>=0.12->lime) (2.6.2)
# Requirement already satisfied: tifffile>=2019.7.26 in d:\anaconda\lib\site-packages (from scikit-image>=0.12->lime) (2021.8.30)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda\lib\site-packages (from matplotlib->lime) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda\lib\site-packages (from matplotlib->lime) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda\lib\site-packages (from matplotlib->lime) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\anaconda\lib\site-packages (from matplotlib->lime) (2.4.7)
# Requirement already satisfied: six in d:\anaconda\lib\site-packages (from cycler>=0.10->matplotlib->lime) (1.16.0)
# Requirement already satisfied: joblib>=0.11 in d:\anaconda\lib\site-packages (from scikit-learn>=0.18->lime) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\anaconda\lib\site-packages (from scikit-learn>=0.18->lime) (2.2.0)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from tqdm->lime) (0.4.4)

# %%
# librería para manejar las flexiones gramaticales en el idioma inglés.
# !pip install inflect
# !pip install pandas-profiling==2.7.1
# Out:
# Requirement already satisfied: inflect in d:\anaconda\lib\site-packages (5.3.0)
# Requirement already satisfied: pandas-profiling==2.7.1 in d:\anaconda\lib\site-packages (2.7.1)
# Requirement already satisfied: ipywidgets>=7.5.1 in d:\anaconda\lib\site-packages (from pandas-profiling==2.7.1) (7.6.3)
# Requirement already satisfied: visions[type_image_path]==0.4.1 in d:\anaconda\lib\site-packages (from pandas-profiling==2.7.1) (0.4.1)
# Requirement already satisfied: scipy>=1.4.1 in d:\anaconda\lib\site-packages (from pandas-profiling==2.7.1) (1.6.2)
# Requirement already satisfied: phik>=0.9.10 in d:\anaconda\lib\site-packages (from pandas-profiling==2.7.1) (0.12.0)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.4 in d:\anaconda\lib\site-packages (from pandas-profiling==2.7.1) (0.1.0)
# Requirement already satisfied: confuse>=1.0.0 in d:\anaconda\lib\site-packages (from pandas-profiling==2.7.1) (1.6.0)
# Requirement already satisfied: requests>=2.23.0 in d:\anaconda\lib\site-packages (from pandas-profiling==2.7.1) (2.25.1)
# Requirement already satisfied: joblib in d:\anaconda\lib\site-packages (from pandas-profiling==2.7.1) (1.0.1)
# Requirement already satisfied: missingno>=0.4.2 in d:\anaconda\lib\site-packages (from pandas-profiling==2.7.1) (0.5.0)
# Requirement already satisfied: numpy>=1.16.0 in d:\anaconda\lib\site-packages (from pandas-profiling==2.7.1) (1.20.3)
# Requirement already satisfied: astropy>=4.0 in d:\anaconda\lib\site-packages (from pandas-profiling==2.7.1) (4.3.1)
# Requirement already satisfied: jinja2>=2.11.1 in d:\anaconda\lib\site-packages (from pandas-profiling==2.7.1) (2.11.3)
# Requirement already satisfied: htmlmin>=0.1.12 in d:\anaconda\lib\site-packages (from pandas-profiling==2.7.1) (0.1.12)
# Requirement already satisfied: tqdm>=4.43.0 in d:\anaconda\lib\site-packages (from pandas-profiling==2.7.1) (4.62.0)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in d:\anaconda\lib\site-packages (from pandas-profiling==2.7.1) (1.3.2)
# Requirement already satisfied: matplotlib>=3.2.0 in d:\anaconda\lib\site-packages (from pandas-profiling==2.7.1) (3.4.2)
# Requirement already satisfied: attrs>=19.3.0 in d:\anaconda\lib\site-packages (from visions[type_image_path]==0.4.1->pandas-profiling==2.7.1) (21.2.0)
# Requirement already satisfied: networkx>=2.4 in d:\anaconda\lib\site-packages (from visions[type_image_path]==0.4.1->pandas-profiling==2.7.1) (2.6.2)
# Requirement already satisfied: imagehash in d:\anaconda\lib\site-packages (from visions[type_image_path]==0.4.1->pandas-profiling==2.7.1) (4.2.1)
# Requirement already satisfied: Pillow in d:\anaconda\lib\site-packages (from visions[type_image_path]==0.4.1->pandas-profiling==2.7.1) (8.3.1)
# Requirement already satisfied: pyerfa>=1.7.3 in d:\anaconda\lib\site-packages (from astropy>=4.0->pandas-profiling==2.7.1) (2.0.0)
# Requirement already satisfied: pyyaml in d:\anaconda\lib\site-packages (from confuse>=1.0.0->pandas-profiling==2.7.1) (5.4.1)
# Requirement already satisfied: ipykernel>=4.5.1 in d:\anaconda\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling==2.7.1) (5.3.4)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in d:\anaconda\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling==2.7.1) (3.5.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in d:\anaconda\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling==2.7.1) (1.0.0)
# Requirement already satisfied: ipython>=4.0.0 in d:\anaconda\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling==2.7.1) (7.26.0)
# Requirement already satisfied: traitlets>=4.3.1 in d:\anaconda\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling==2.7.1) (5.0.5)
# Requirement already satisfied: nbformat>=4.2.0 in d:\anaconda\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling==2.7.1) (5.1.3)
# Requirement already satisfied: jupyter-client in d:\anaconda\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling==2.7.1) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in d:\anaconda\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling==2.7.1) (6.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in d:\anaconda\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling==2.7.1) (3.0.17)
# Requirement already satisfied: backcall in d:\anaconda\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling==2.7.1) (0.2.0)
# Requirement already satisfied: decorator in d:\anaconda\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling==2.7.1) (5.0.9)
# Requirement already satisfied: setuptools>=18.5 in d:\anaconda\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling==2.7.1) (52.0.0.post20210125)
# Requirement already satisfied: matplotlib-inline in d:\anaconda\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling==2.7.1) (0.1.2)
# Requirement already satisfied: jedi>=0.16 in d:\anaconda\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling==2.7.1) (0.17.2)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling==2.7.1) (0.4.4)
# Requirement already satisfied: pygments in d:\anaconda\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling==2.7.1) (2.9.0)
# Requirement already satisfied: pickleshare in d:\anaconda\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling==2.7.1) (0.7.5)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in d:\anaconda\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling==2.7.1) (0.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\anaconda\lib\site-packages (from jinja2>=2.11.1->pandas-profiling==2.7.1) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling==2.7.1) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling==2.7.1) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\anaconda\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling==2.7.1) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling==2.7.1) (0.10.0)
# Requirement already satisfied: six in d:\anaconda\lib\site-packages (from cycler>=0.10->matplotlib>=3.2.0->pandas-profiling==2.7.1) (1.16.0)
# Requirement already satisfied: seaborn in d:\anaconda\lib\site-packages (from missingno>=0.4.2->pandas-profiling==2.7.1) (0.11.2)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in d:\anaconda\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->pandas-profiling==2.7.1) (3.2.0)
# Requirement already satisfied: jupyter-core in d:\anaconda\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->pandas-profiling==2.7.1) (4.7.1)
# Requirement already satisfied: ipython-genutils in d:\anaconda\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->pandas-profiling==2.7.1) (0.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in d:\anaconda\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.1->pandas-profiling==2.7.1) (0.17.3)
# Requirement already satisfied: pytz>=2017.3 in d:\anaconda\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->pandas-profiling==2.7.1) (2018.9)
# Requirement already satisfied: wcwidth in d:\anaconda\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling==2.7.1) (0.2.5)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests>=2.23.0->pandas-profiling==2.7.1) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda\lib\site-packages (from requests>=2.23.0->pandas-profiling==2.7.1) (1.26.6)
# Requirement already satisfied: idna<3,>=2.5 in d:\anaconda\lib\site-packages (from requests>=2.23.0->pandas-profiling==2.7.1) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in d:\anaconda\lib\site-packages (from requests>=2.23.0->pandas-profiling==2.7.1) (4.0.0)
# Requirement already satisfied: notebook>=4.4.1 in d:\anaconda\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling==2.7.1) (6.4.2)
# Requirement already satisfied: Send2Trash>=1.5.0 in d:\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling==2.7.1) (1.5.0)
# Requirement already satisfied: terminado>=0.8.3 in d:\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling==2.7.1) (0.9.4)
# Requirement already satisfied: argon2-cffi in d:\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling==2.7.1) (20.1.0)
# Requirement already satisfied: pyzmq>=17 in d:\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling==2.7.1) (22.2.1)
# Requirement already satisfied: nbconvert in d:\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling==2.7.1) (6.1.0)
# Requirement already satisfied: prometheus-client in d:\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling==2.7.1) (0.11.0)
# Requirement already satisfied: pywin32>=1.0 in d:\anaconda\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets>=7.5.1->pandas-profiling==2.7.1) (228)
# Requirement already satisfied: pywinpty>=0.5 in d:\anaconda\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling==2.7.1) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in d:\anaconda\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling==2.7.1) (1.14.6)
# Requirement already satisfied: pycparser in d:\anaconda\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling==2.7.1) (2.20)
# Requirement already satisfied: PyWavelets in d:\anaconda\lib\site-packages (from imagehash->visions[type_image_path]==0.4.1->pandas-profiling==2.7.1) (1.1.1)
# Requirement already satisfied: testpath in d:\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling==2.7.1) (0.5.0)
# Requirement already satisfied: entrypoints>=0.2.2 in d:\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling==2.7.1) (0.3)
# Requirement already satisfied: bleach in d:\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling==2.7.1) (4.0.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in d:\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling==2.7.1) (0.8.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in d:\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling==2.7.1) (0.5.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling==2.7.1) (1.4.3)
# Requirement already satisfied: jupyterlab-pygments in d:\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling==2.7.1) (0.1.2)
# Requirement already satisfied: defusedxml in d:\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling==2.7.1) (0.7.1)
# Requirement already satisfied: async-generator in d:\anaconda\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling==2.7.1) (1.10)
# Requirement already satisfied: nest-asyncio in d:\anaconda\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling==2.7.1) (1.5.1)
# Requirement already satisfied: webencodings in d:\anaconda\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling==2.7.1) (0.5.1)
# Requirement already satisfied: packaging in d:\anaconda\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling==2.7.1) (21.0)

# %%
# librería Natural Language Toolkit, usada para trabajar con textos 
import nltk
# Punkt permite separar un texto en frases.
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\jhorm\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Descarga todas las palabras vacias, es decir, aquellas que no aportan nada al significado del texto
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\jhorm\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Descarga de paquete WordNetLemmatizer, este es usado para encontrar el lema de cada palabra
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\jhorm\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Importación de librerias
import pandas as pd
import numpy as np
import sys
from pandas_profiling import ProfileReport

import re, string, unicodedata
import contractions
import inflect
from nltk import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import LancasterStemmer, WordNetLemmatizer

from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer, HashingVectorizer
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import BernoulliNB
from sklearn.metrics import classification_report, confusion_matrix, plot_precision_recall_curve
from sklearn.base import BaseEstimator, ClassifierMixin

import matplotlib.pyplot as plt
import seaborn as sns
import neattext.functions as nfx
from textblob import TextBlob
from collections import Counter

# Interpretación del modelo
import eli5
import lime
from lime import lime_tabular

# %% [markdown]
# ## 1. Perfilamiento y entendimiento de los datos

# %% [markdown]
# #### Lectura de los datos.

# %%
# Uso de la libreria pandas para la lectura de archivos
data=pd.read_csv('train.txt', sep=';', encoding = 'utf-8')
# Asignación a una nueva variable de los datos leidos
data_t=data

# %%
data.shape
# Out:
# (16000, 2)

# %%
data.isnull().sum()
# Out:
# Text       0
# Emotion    0
# dtype: int64

# %%
data.dtypes
# Out:
# Text       object
# Emotion    object
# dtype: object

# %%
data['Emotion'].value_counts()
# Out:
# joy         5362
# sadness     4666
# anger       2159
# fear        1937
# love        1304
# surprise     572
# Name: Emotion, dtype: int64

# %%
plt.figure(figsize=(7,7))
sns.countplot(x='Emotion',data=data)
plt.show()

# %% [markdown]
# Como se puede ver, la información es no balanceada. Hay categorías de la variable emoción que no tienen muchos datos en comparación a otras. Por ejemplo, surprise aparece muy poco, en cambio joy es la emoción que más aparece.

# %% [markdown]
# ### Exploración
# + Text Cleaning
# + Sentiment Analysis
# + Keyword Extraction
#     - Keywords for each emotion
#     - Wordcloud

# %% [markdown]
# #### Sentiment Analysis

# %%
def get_sentiment(text):
    blob = TextBlob(text)
    sentiment = blob.sentiment.polarity
    if sentiment > 0:
        result = 'Positivo'
    elif sentiment < 0:
        result = 'Negativo'
    else:
        result = 'Neutral'
    return result

# %%
# Prueba de función
get_sentiment("I hate Mondays")
# Out:
# 'Negativo'

# %%
data['Sentimiento'] = data['Text'].apply(get_sentiment)

# %%
data['Sentimiento'].value_counts()
# Out:
# Positivo    7634
# Negativo    5189
# Neutral     3177
# Name: Sentimiento, dtype: int64

# %%
# Comparación de Emotion con Sentimiento
data.groupby(['Emotion','Sentimiento']).size()
# Out:
# Emotion   Sentimiento
# anger     Negativo       1047
#           Neutral         545
#           Positivo        567
# fear      Negativo        871
#           Neutral         452
#           Positivo        614
# joy       Negativo        589
#           Neutral         776
#           Positivo       3997
# love      Negativo        244
#           Neutral         179
#           Positivo        881
# sadness   Negativo       2205
#           Neutral        1165
#           Positivo       1296
# surprise  Negativo        233
#           Neutral          60
#           Positivo        279
# dtype: int64

# %%
sns.catplot(x='Emotion', hue='Sentimiento', data=data, height=6, kind='count')
plt.show()
#sns.catplot

# %% [markdown]
# #### Text Cleaning
# + Remove noise
#     - Stopwords
#     - Special characters
#     - Punctuations

# %%
data['Clean_Text']=data['Text'].apply(nfx.remove_stopwords)

# %%
data['Clean_Text']=data['Clean_Text'].apply(nfx.remove_userhandles)

# %%
data['Clean_Text']=data['Clean_Text'].apply(nfx.remove_punctuations)

# %%
data[['Text','Clean_Text']]
# Out:
#                                                     Text  \
# 0                                i didnt feel humiliated
# 1      i can go from feeling so hopeless to so damned...
# 2       im grabbing a minute to post i feel greedy wrong
# 3      i am ever feeling nostalgic about the fireplac...
# 4                                   i am feeling grouchy
# ...                                                  ...
# 15995  i just had a very brief time in the beanbag an...
# 15996  i am now turning and i feel pathetic that i am...
# 15997                     i feel strong and good overall
# 15998  i feel like this was such a rude comment and i...
# 15999  i know a lot but i feel so stupid because i ca...
#
#                                               Clean_Text
# 0                                  didnt feel humiliated
# 1            feeling hopeless damned hopeful cares awake
# 2              im grabbing minute post feel greedy wrong
# 3              feeling nostalgic fireplace know property
# 4                                        feeling grouchy
# ...                                                  ...
# 15995      brief time beanbag said anna feel like beaten
# 15996  turning feel pathetic waiting tables subbing t...
# 15997                           feel strong good overall
# 15998                     feel like rude comment im glad
# 15999                       know lot feel stupid portray
#
# [16000 rows x 2 columns]

# %% [markdown]
# #### Keyword Extraction
# + Extract most common words per class of emotion

# %%
def extract_keywords(text,num=10):
    tokens = [ tok for tok in text.split()]
    most_common_tokens = Counter(tokens).most_common(num)
    return dict(most_common_tokens)

# %%
# list of emotions
emotions_list = data['Emotion'].unique().tolist()
emotions_list
# Out:
# ['sadness', 'anger', 'love', 'surprise', 'fear', 'joy']

# %%
# Se puede hacer para cada emoción
joy_list = data[data['Emotion'] == 'joy']['Clean_Text'].tolist()

# %%
joy_docx = ' '.join(joy_list)

# %%
# Extract Keywords
keywords_joy = extract_keywords(joy_docx)

# %%
# Top 50 keywords of joy
keywords_joy
# Out:
# {'feel': 3928,
#  'feeling': 1539,
#  'like': 1006,
#  'im': 799,
#  'time': 290,
#  'know': 240,
#  'want': 203,
#  'people': 203,
#  'think': 198,
#  'good': 196}

# %%
# Plot
def plot_most_common_words(mydict,emotion_name):
    df_plot = pd.DataFrame(mydict.items(),columns=['token','count'])
    plt.figure(figsize=(15,10))
    plt.title("Plot of {} Most Common Keywords".format(emotion_name))
    sns.barplot(x='token',y='count',data=df_plot)
    plt.xticks(rotation=45)
    plt.savefig("PlotOf{}".format(emotion_name))
    plt.show()

# %%
plot_most_common_words(keywords_joy,"Joy")

# %%
anger_list = data[data['Emotion'] == 'anger']['Clean_Text'].tolist()
# Document
anger_docx = ' '.join(anger_list)
#Extract Keywords
keywords_anger = extract_keywords(anger_docx)

# %%
plot_most_common_words(keywords_anger,"Anger")

# %%
# Importar Word Cloud
from wordcloud import WordCloud

# %%
# Creación de una gráfica alternativa para visualizar la frecuencia de las palabras.
def plot_wordcloud(docx):
    wc = WordCloud().generate(docx)
    plt.figure(figsize=(20,10))
    plt.imshow(wc, interpolation='bilinear')
    plt.axis('off')
    plt.show()

# %%
# Muestra de palabras relacionadas a joy con una nube de palabras.
plot_wordcloud(joy_docx)

# %%
# Muestra de palabras relacionadas a joy con una nube de palabras.
plot_wordcloud(surprise_docx)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-169-86b78e5e6dd8> in <module>
#       1 # Muestra de palabras relacionadas a joy con una nube de palabras.
# ----> 2 plot_wordcloud(surprise_docx)
#
# NameError: name 'surprise_docx' is not defined

# %% [markdown]
# Entendiendo la distribución básica de las emociones y algunas de las palabras a las que son asociadas frecuentemente, se puede proseguir a crear y entrenar distintos modelos en búsqueda de la solución óptima.

# %% [markdown]
# ## 2. Modelaje

# %% [markdown]
# ### MultinomialNB (Andrés Felipe Sánchez - 201821941)

# %%
# Importar modelo
from sklearn.naive_bayes import MultinomialNB
# Vectorizer
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
# Importar presentación de métricas
from sklearn.metrics import accuracy_score,confusion_matrix, classification_report, plot_confusion_matrix
# Importar división de datos en secciones de entrenamiento y de prueba.
from sklearn.model_selection import train_test_split

# %%
# Features a analizar
Xfeatures = data['Clean_Text']
# Variable objetivo
ylabels = data['Emotion']
Xfeatures

# %%
# Convertir la lista de features en un vector.
cv = CountVectorizer()
X = cv.fit_transform(Xfeatures)

# %%
cv.get_feature_names()

# %%
# Partición de los datos
X_train,X_test,y_train,y_test = train_test_split(X,ylabels,test_size=0.3,random_state=42)

# %%
nv_model = MultinomialNB()
nv_model.fit(X_train,y_train)

# %%
# Métrica de exactitud promedio
nv_model.score(X_test,y_test)

# %%
# Predicción con conjunto de datos de prueba
y_pred_for_nv = nv_model.predict(X_test)
y_pred_for_nv

# %%
# Métricas de clasificación
print(classification_report(y_test,y_pred_for_nv))

# %% [markdown]
# Dado que estas métricas son las aplicadas a modelos de clasificación, se puede saber inmediatamente que la exactitud del modelo señala con qué frecuencia es correcto el clasificador de manera general, que la precisión de cada clase apunta al porcentaje de asignaciones a esa clase que fueron correctas, que el recall representa cuántas de los valores reales predijo correctamente el modelo, y que el puntaje F1 es la media armónica entre la precisión y el recall.

# %%
# Matriz de confusión
#confusion_matrix(y_test,y_pred_for_nv)
plot_confusion_matrix(nv_model,X_test,y_test)

# %% [markdown]
# ### Regresión Logística (Daniel Rincón G. – 201822574)

# %%
# Importar modelos
from sklearn.linear_model import LogisticRegression
# Vectorizer
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
# Importar presentación de métricas
from sklearn.metrics import accuracy_score,confusion_matrix, classification_report, plot_confusion_matrix
# Importar división de datos en secciones de entrenamiento y de prueba.
from sklearn.model_selection import train_test_split

# %%
# Features a analizar
Xfeatures = data['Clean_Text']
# Variable objetivo
ylabels = data['Emotion']
Xfeatures

# %%
# Convertir la lista de features en un vector.
cv = CountVectorizer()
X = cv.fit_transform(Xfeatures)

# %%
cv.get_feature_names()

# %%
# Partición de los datos
X_train,X_test,y_train,y_test = train_test_split(X,ylabels,test_size=0.3,random_state=42)

# %%
# Creación del modelo
lr_model = LogisticRegression()
# Modelo alcanza número máximo de iteraciones pero genera un resultado adecuado.
lr_model.fit(X_train,y_train)

# %%
# Métrica de exactitud promedio
lr_model.score(X_test,y_test)

# %%
# Predicción con conjunto de datos de prueba
y_pred_for_nv = lr_model.predict(X_test)
y_pred_for_nv

# %%
# Métricas de clasificación
print(classification_report(y_test,y_pred_for_nv))

# %%
# Matriz de confusión
#confusion_matrix(y_test,y_pred_for_nv)
plot_confusion_matrix(lr_model,X_test,y_test)

# %%
# Peso de los features de cada categoría
class_names = ylabels.unique().tolist()
feature_names = cv.get_feature_names()
eli5.show_weights(lr_model, feature_names=feature_names, target_names=class_names, top=20)

# %% [markdown]
# ### SGD Classifier (Jhorman Caballero - 201812920)

# %%
# Instalaciones necesarias
# !pip install parfit

# %%
#Librerias necesarias
from sklearn.model_selection import ParameterGrid
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import roc_auc_score
import parfit.parfit as pf

# %%
# Features a analizar
Xfeatures = data['Clean_Text']
# Variable objetivo
ylabels = data['Emotion']
Xfeatures

# %%
# Convertir la lista de features en un vector.
cv = CountVectorizer()
X = cv.fit_transform(Xfeatures)

# %%
xtrain, xtest, ytrain, ytest = train_test_split(X, ylabels, test_size = 0.3)

sgdc = SGDClassifier(max_iter=1000, tol=0.01)
 
sgdc.fit(xtrain, ytrain)

# %%
score = sgdc.score(xtrain, ytrain)
print("Training score: ", score)

# %%
ypred = sgdc.predict(xtest)

plot_confusion_matrix(sgdc,xtest,ytest)
plt.show()

# %%
cr = classification_report(ytest, ypred)
print(cr)
